# %% [markdown]
# <a href="https://colab.research.google.com/github/Thisari2002/Agro-company-payment/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
data = pd.read_csv('/content/drugSensitivity.csv')

# %%
data.head()
# Out:
#    COSMIC_ID CELL_LINE_NAME     TCGA_DESC  DRUG_ID    DRUG_NAME   LN_IC50  \
# 0     924186            KGN  UNCLASSIFIED     1006   Cytarabine -1.370897
# 1     907064        HT-1080  UNCLASSIFIED     1613       VE-822  4.456730
# 2     925347     PANC-08-13          PAAD     1062  Selumetinib  4.604022
# 3     753534            BEN  UNCLASSIFIED     1248    Daporinad -1.927461
# 4     910853          CHL-1          SKCM     1780  GSK3337463A  5.013688
#
#         AUC   Z_SCORE GDSC Tissue descriptor 1  GDSC Tissue descriptor 2  \
# 0  0.662249 -1.285923        urogenital_system                     ovary
# 1  0.966289  0.743356              soft_tissue              fibrosarcoma
# 2  0.944950  0.735358                 pancreas                  pancreas
# 3  0.664518  0.526028               lung_NSCLC  lung_NSCLC_not specified
# 4  0.975140 -0.251060                     skin                  melanoma
#
#   Cancer Type (matching TCGA label) Microsatellite instability Status (MSI)  \
# ...
